# %%
import pandas as pd

# %%
df=pd.read_csv("CSCI.635.03 - Intro to Machine Learning_GradesExport_2023-09-07-15-35.csv")

# %%
df
# Out:
#     Username              Last Name             First Name            Email  \
# 0    #ac2434             Chiplunkar          Atharva Manoj   ac2434@rit.edu
# 1    #ak6913                 Kherde          Ashwin Sharad   ak6913@rit.edu
# 2   #aln4739                 Nguyen                    Anh  aln4739@rit.edu
# 3    #am9559                  Mulky                Anikhet   am9559@rit.edu
# 4    #as1896                Stewart                 Athina   as1896@rit.edu
# 5    #ay1656           Yaber Llanos              Alejandro   ay1656@rit.edu
# 6   #bsg8294              Giacalone                    Ben  bsg8294@rit.edu
# 7   #btn6364                 Nguyen                    Bao  btn6364@rit.edu
# 8   #can1767                    Nau                 Calvin  can1767@rit.edu
# 9   #fva6937  Voltolini De Azambuja               Fernando  fva6937@rit.edu
# 10  #gnk1165                   Krot                 Gerrit  gnk1165@rit.edu
# ...

# %%
l=[]

# %%
for i,k in df[['Email']].sample(frac=1).itertuples():
    l.append(k)

# %%
l
# Out:
# ['hl3352@rit.edu',
#  'mb2856@rit.edu',
#  'xh1165@rit.edu',
#  'ss7696@rit.edu',
#  'ta5900@rit.edu',
#  'qnd5128@rit.edu',
#  'pg3328@rit.edu',
#  'ac2434@rit.edu',
#  'ak6913@rit.edu',
#  'aln4739@rit.edu',
#  'km1139@rit.edu',
#  'jpd2690@rit.edu',
#  'am9559@rit.edu',
#  'ks2648@rit.edu',
#  'mk1651@rit.edu',
#  'jp5811@rit.edu',
#  'btn6364@rit.edu',
#  'ay1656@rit.edu',
#  'kn1894@rit.edu',
#  'as1896@rit.edu',
#  'mhm3244@rit.edu',
#  'bsg8294@rit.edu',
#  'fva6937@rit.edu',
#  'gnk1165@rit.edu',
#  'can1767@rit.edu',
#  'rs7566@rit.edu',
#  'sd5223@rit.edu',
#  'xl9694@rit.edu']

# %%
n=3
c=1
for i in range(0, len(l), n):
    chunk = l[i:i+n]
    print("Group ",str(c),str(chunk))
    c+=1
# Out:
# Group  1 ['hl3352@rit.edu', 'mb2856@rit.edu', 'xh1165@rit.edu']
# Group  2 ['ss7696@rit.edu', 'ta5900@rit.edu', 'qnd5128@rit.edu']
# Group  3 ['pg3328@rit.edu', 'ac2434@rit.edu', 'ak6913@rit.edu']
# Group  4 ['aln4739@rit.edu', 'km1139@rit.edu', 'jpd2690@rit.edu']
# Group  5 ['am9559@rit.edu', 'ks2648@rit.edu', 'mk1651@rit.edu']
# Group  6 ['jp5811@rit.edu', 'btn6364@rit.edu', 'ay1656@rit.edu']
# Group  7 ['kn1894@rit.edu', 'as1896@rit.edu', 'mhm3244@rit.edu']
# Group  8 ['bsg8294@rit.edu', 'fva6937@rit.edu', 'gnk1165@rit.edu']
# Group  9 ['can1767@rit.edu', 'rs7566@rit.edu', 'sd5223@rit.edu']
# Group  10 ['xl9694@rit.edu']

# %%
'''
Group  1 ['hl3352@rit.edu', 'xl9694@rit.edu','xh1165@rit.edu']
Group  2 ['ss7696@rit.edu', 'ta5900@rit.edu', 'qnd5128@rit.edu']
Group  3 ['pg3328@rit.edu', 'ac2434@rit.edu', 'ak6913@rit.edu']
Group  4 ['aln4739@rit.edu', 'km1139@rit.edu', 'jpd2690@rit.edu']
Group  5 ['am9559@rit.edu', 'ks2648@rit.edu', 'mk1651@rit.edu']
Group  6 ['jp5811@rit.edu', 'btn6364@rit.edu', 'ay1656@rit.edu']
Group  7 ['kn1894@rit.edu', 'as1896@rit.edu', 'mhm3244@rit.edu']
Group  8 ['bsg8294@rit.edu', 'fva6937@rit.edu', 'gnk1165@rit.edu']
Group  9 ['can1767@rit.edu', 'rs7566@rit.edu', 'sd5223@rit.edu','mb2856@rit.edu']
'''

# %%
"""
Group  1 ['km1139@rit.edu', 'sd5223@rit.edu', 'jp5811@rit.edu']
Group  2 ['fva6937@rit.edu', 'ak6913@rit.edu', 'ss7696@rit.edu']
Group  3 ['xh1165@rit.edu', 'qnd5128@rit.edu', 'as1896@rit.edu']
Group  4 ['ta5900@rit.edu', 'mk1651@rit.edu', 'btn6364@rit.edu']
Group  5 ['rs7566@rit.edu', 'ac2434@rit.edu', 'gnk1165@rit.edu']
Group  6 ['aln4739@rit.edu', 'mhm3244@rit.edu', 'mb2856@rit.edu']
Group  7 ['xl9694@rit.edu', 'hl3352@rit.edu', 'kn1894@rit.edu']
Group  8 ['jpd2690@rit.edu', 'can1767@rit.edu', 'pg3328@rit.edu']
Group  9 ['ay1656@rit.edu', 'bsg8294@rit.edu', 'ks2648@rit.edu','am9559@rit.edu']
"""
